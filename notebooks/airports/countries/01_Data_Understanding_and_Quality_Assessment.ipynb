# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
countries = pd.read_csv(
    "../../../data/raw/airports/countries.csv"
)

# %%
countries.head()
# Out:
#        id code                  name continent  \
# 0  302672   AD               Andorra        EU
# 1  302618   AE  United Arab Emirates        AS
# 2  302619   AF           Afghanistan        AS
# 3  302722   AG   Antigua and Barbuda       NaN
# 4  302723   AI              Anguilla       NaN
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Andorra
# 1  https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2          https://en.wikipedia.org/wiki/Afghanistan
# 3  https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 4             https://en.wikipedia.org/wiki/Anguilla
#
#                                  keywords
# 0                       Andorran airports
# 1  UAE,مطارات في الإمارات العربية المتحدة
# 2                                     NaN
# 3                       Antiguan airports
# 4                                     NaN

# %%
countries.tail()
# Out:
#          id code                           name continent  \
# 244  302609   YT                        Mayotte        AF
# 245  302610   ZA                   South Africa        AF
# 246  302611   ZM                         Zambia        AF
# 247  302612   ZW                       Zimbabwe        AF
# 248  302613   ZZ  Unknown or unassigned country        AF
#
#                                         wikipedia_link  \
# 244              https://en.wikipedia.org/wiki/Mayotte
# 245         https://en.wikipedia.org/wiki/South_Africa
# 246               https://en.wikipedia.org/wiki/Zambia
# 247             https://en.wikipedia.org/wiki/Zimbabwe
# 248  https://en.wikipedia.org/wiki/Unknown_or_unass...
#
#                                       keywords
# 244                        Airports in Mayotte
# 245                     South African airports
# 246                           Zambian airports
# 247                         Zimbabwan airports
# ...

# %%
countries.sample(5)
# Out:
#          id code                      name continent  \
# 38   302562   CF  Central African Republic        AF
# 126  302699   LI             Liechtenstein        EU
# 169  302655   OM                      Oman        AS
# 204  302614   SS               South Sudan        AF
# 51   302628   CX          Christmas Island        AS
#
#                                         wikipedia_link  \
# 38   https://en.wikipedia.org/wiki/Central_African_...
# 126        https://en.wikipedia.org/wiki/Liechtenstein
# 169                 https://en.wikipedia.org/wiki/Oman
# 204          https://en.wikipedia.org/wiki/South_Sudan
# 51      https://en.wikipedia.org/wiki/Christmas_Island
#
#                                  keywords
# 38   Airports in Central African Republic
# 126             Airports in Liechtenstein
# 169                           مطارات عمان
# 204               South Sudanese airports
# 51           Airports in Christmas Island

# %%
print("Rows :", countries.shape[0])
print("Columns :", countries.shape[1])
# Out:
# Rows : 249
# Columns : 6

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              249 non-null    int64
#  1   code            248 non-null    object
#  2   name            249 non-null    object
#  3   continent       208 non-null    object
#  4   wikipedia_link  249 non-null    object
#  5   keywords        233 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 11.8+ KB

# %%
missing = pd.DataFrame({
    "Missing Values": countries.isnull().sum(),
    "Percentage": (
        countries.isnull().mean()*100
    ).round(2)
})

missing
# Out:
#                 Missing Values  Percentage
# id                           0        0.00
# code                         1        0.40
# name                         0        0.00
# continent                   41       16.47
# wikipedia_link               0        0.00
# keywords                    16        6.43

# %%
print(
    countries.duplicated().sum()
)
# Out:
# 0

# %%
countries["code"].duplicated().sum()
# Out:
# np.int64(0)

# %%
countries.head()

countries.info()

countries.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              249 non-null    int64
#  1   code            248 non-null    object
#  2   name            249 non-null    object
#  3   continent       208 non-null    object
#  4   wikipedia_link  249 non-null    object
#  5   keywords        233 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 11.8+ KB
# Index(['id', 'code', 'name', 'continent', 'wikipedia_link', 'keywords'], dtype='object')
